# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("ecommerce_500k.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (25885, 30)
#    order_id  customer_id  product_id  order_date    category sub_category  \
# 0   1000001        25795          90  2022-07-31    Clothing          Men
# 1   1000002        10860        1917  2023-09-25  Automotive     Car Care
# 2   1000003        86820         805  2022-03-26       Books    Textbooks
# 3   1000004        64886        3379  2022-11-03       Books  Non-Fiction
# 4   1000005        16265        4604  2022-06-30    Clothing        Women
#
#    product_base_price  discount_percentage  final_price  quantity  ...  \
# 0               70.41                 25.0        52.81       1.0  ...
# 1                6.02                 10.0         5.42       3.0  ...
# 2               78.85                 20.0        63.08       2.0  ...
# 3               58.42                 25.0        43.82       4.0  ...
# 4               73.38                 15.0        62.37       1.0  ...
#
#          city  loyalty_tier is_first_purchase  customer_lifetime_value  \
# 0   Bangalore        Bronze               0.0                   457.77
# 1     Toronto        Bronze               0.0                  1606.42
# 2     Chicago        Silver               0.0                   252.16
# 3      Sydney        Bronze               0.0                   645.12
# 4  Manchester        Bronze               1.0                  1103.24
#
#   session_duration_mins  pages_viewed  clicks_to_purchase  is_returned  \
# 0                   4.6          35.0                 7.0          0.0
# 1                   2.9           8.0                 8.0          0.0
# 2                   5.5          38.0                 8.0          0.0
# 3                   6.1          30.0                 9.0          0.0
# 4                   1.6          38.0                11.0          0.0
#
#   return_reason is_cancelled
# 0           NaN          0.0
# 1           NaN          0.0
# 2           NaN          0.0
# 3           NaN          0.0
# 4           NaN          0.0
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25885 entries, 0 to 25884
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 25885 non-null  int64
#  1   customer_id              25885 non-null  int64
#  2   product_id               25885 non-null  int64
#  3   order_date               25885 non-null  object
#  4   category                 25885 non-null  object
#  5   sub_category             25884 non-null  object
#  6   product_base_price       25884 non-null  float64
#  7   discount_percentage      25884 non-null  float64
#  8   final_price              25884 non-null  float64
#  9   quantity                 25884 non-null  float64
#  10  total_amount             25884 non-null  float64
#  11  shipping_cost            25089 non-null  float64
#  12  shipping_method          25884 non-null  object
#  13  days_to_deliver          25098 non-null  float64
#  14  payment_method           25884 non-null  object
#  15  rating                   25117 non-null  float64
#  16  num_reviews              25884 non-null  float64
#  17  customer_age             25075 non-null  float64
#  18  customer_gender          25884 non-null  object
#  19  country                  25884 non-null  object
#  20  city                     25884 non-null  object
#  21  loyalty_tier             25884 non-null  object
#  22  is_first_purchase        25884 non-null  float64
#  23  customer_lifetime_value  25045 non-null  float64
#  24  session_duration_mins    25137 non-null  float64
#  25  pages_viewed             25041 non-null  float64
#  26  clicks_to_purchase       25884 non-null  float64
#  27  is_returned              25884 non-null  float64
#  28  return_reason            3081 non-null   object
#  29  is_cancelled             25884 non-null  float64
# dtypes: float64(17), int64(3), object(10)
# memory usage: 5.9+ MB

# %%
df.describe(include="all")
# Out:
#             order_id   customer_id    product_id  order_date        category  \
# count   2.588500e+04  25885.000000  25885.000000       25885           25885
# unique           NaN           NaN           NaN        1095              11
# top              NaN           NaN           NaN  2022-02-26  Food & Grocery
# freq             NaN           NaN           NaN          43            2634
# mean    1.012943e+06  54811.223875   2517.787213         NaN             NaN
# std     7.472500e+03  26279.378155   1441.329838         NaN             NaN
# min     1.000001e+06  10002.000000      1.000000         NaN             NaN
# 25%     1.006472e+06  31834.000000   1275.000000         NaN             NaN
# 50%     1.012943e+06  54757.000000   2535.000000         NaN             NaN
# 75%     1.019414e+06  77819.000000   3764.000000         NaN             NaN
# max     1.025885e+06  99987.000000   5000.000000         NaN             NaN
#
#        sub_category  product_base_price  discount_percentage   final_price  \
# count         25884        25884.000000         25884.000000  25884.000000
# unique           45                 NaN                  NaN           NaN
# top         Outdoor                 NaN                  NaN           NaN
# freq           1614                 NaN                  NaN           NaN
# mean            NaN           84.409250            14.557062     71.983004
# std             NaN           79.405332            12.853504     68.995327
# min             NaN            5.000000             0.000000      2.580000
# 25%             NaN           27.870000             5.000000     23.400000
# 50%             NaN           60.315000            10.000000     50.500000
# 75%             NaN          115.195000            20.000000     97.642500
# max             NaN          849.510000            50.000000    764.560000
#
#             quantity  ...       city  loyalty_tier is_first_purchase  \
# count   25884.000000  ...      25884         25884      25884.000000
# unique           NaN  ...         15             4               NaN
# top              NaN  ...  Bangalore        Bronze               NaN
# freq             NaN  ...       1804         11598               NaN
# mean        2.276773  ...        NaN           NaN          0.275151
# std         1.728279  ...        NaN           NaN          0.446599
# min         1.000000  ...        NaN           NaN          0.000000
# 25%         1.000000  ...        NaN           NaN          0.000000
# 50%         2.000000  ...        NaN           NaN          0.000000
# 75%         3.000000  ...        NaN           NaN          1.000000
# max        10.000000  ...        NaN           NaN          1.000000
#
#         customer_lifetime_value session_duration_mins  pages_viewed  \
# count              25045.000000          25137.000000  25041.000000
# unique                      NaN                   NaN           NaN
# top                         NaN                   NaN           NaN
# freq                        NaN                   NaN           NaN
# mean                 860.201792              8.475264     24.921609
# std                  815.087412              8.088621     14.123151
# min                   50.020000              0.500000      1.000000
# 25%                  283.730000              2.800000     13.000000
# 50%                  609.300000              5.900000     25.000000
# 75%                 1171.790000             11.600000     37.000000
# max                11606.040000            121.400000     49.000000
#
#         clicks_to_purchase   is_returned       return_reason  is_cancelled
# count         25884.000000  25884.000000                3081  25884.000000
# unique                 NaN           NaN                   5           NaN
# top                    NaN           NaN  Better Price Found           NaN
# freq                   NaN           NaN                 658           NaN
# mean             10.015724      0.119031                 NaN      0.062471
# std               5.473248      0.323831                 NaN      0.242014
# min               1.000000      0.000000                 NaN      0.000000
# 25%               5.000000      0.000000                 NaN      0.000000
# 50%              10.000000      0.000000                 NaN      0.000000
# 75%              15.000000      0.000000                 NaN      0.000000
# max              19.000000      1.000000                 NaN      1.000000
#
# [11 rows x 30 columns]

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
print(missing)

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
plt.figure(figsize=(8,5))
plt.hist(df["final_price"], bins=50)
plt.title("Final Price Distribution")
plt.xlabel("Final Price")
plt.ylabel("Frequency")
plt.show()

# %%
print("Product Base Price Skew:", df["product_base_price"].skew())
print("Final Price Skew:", df["final_price"].skew())
print("Total Amount Skew:", df["total_amount"].skew())
# Out:
# Product Base Price Skew: 2.010691522226667
# Final Price Skew: 2.082914379226759
# Total Amount Skew: 3.95313768689661

# %%
categorical_cols = df.select_dtypes(include="object").columns.tolist()
print(categorical_cols)
# Out:
# ['order_date', 'category', 'sub_category', 'shipping_method', 'payment_method', 'customer_gender', 'country', 'city', 'loyalty_tier', 'return_reason']

# %%
for col in categorical_cols:
    print(col, ":", df[col].nunique())
# Out:
# order_date : 1095
# category : 11
# sub_category : 45
# shipping_method : 4
# payment_method : 6
# customer_gender : 3
# country : 8
# city : 15
# loyalty_tier : 4
# return_reason : 5

# %%
print(df["is_returned"].value_counts())
print(df["is_returned"].value_counts(normalize=True) * 100)
# Out:
# is_returned
# 0.0    22803
# 1.0     3081
# Name: count, dtype: int64
# is_returned
# 0.0    88.096894
# 1.0    11.903106
# Name: proportion, dtype: float64

# %%
print(pd.crosstab(df["loyalty_tier"], df["is_returned"]))
# Out:
# is_returned     0.0   1.0
# loyalty_tier
# Bronze        10178  1420
# Gold           3948   500
# Platinum       1881   258
# Silver         6796   903

# %%
numeric_df = df.select_dtypes(include=np.number)
corr = numeric_df.corr()

print(corr["is_returned"].sort_values(ascending=False))
# Out:
# is_returned                1.000000
# customer_age               0.005699
# pages_viewed               0.004782
# discount_percentage        0.002921
# final_price                0.001912
# customer_lifetime_value    0.001017
# days_to_deliver            0.000636
# product_base_price         0.000318
# quantity                  -0.000948
# order_id                  -0.001602
# session_duration_mins     -0.002028
# total_amount              -0.002901
# rating                    -0.003298
# shipping_cost             -0.003778
# product_id                -0.004510
# customer_id               -0.005183
# clicks_to_purchase        -0.005721
# num_reviews               -0.006716
# is_first_purchase         -0.008479
# is_cancelled              -0.094885
# Name: is_returned, dtype: float64

# %%
numeric_cols = [
    "product_base_price",
    "final_price",
    "shipping_cost",
    "days_to_deliver",
    "rating",
    "customer_age",
    "customer_lifetime_value",
    "session_duration_mins",
    "pages_viewed"
]

robust_cols = ["total_amount"]

nominal_cols = [
    "category",
    "sub_category",
    "shipping_method",
    "payment_method",
    "customer_gender",
    "country"
]

ordinal_cols = ["loyalty_tier"]

numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

robust_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", RobustScaler())
])

nominal_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

ordinal_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OrdinalEncoder(categories=[["Bronze","Silver","Gold","Platinum"]]))
])

preprocessor = ColumnTransformer([
    ("num", numeric_pipeline, numeric_cols),
    ("robust", robust_pipeline, robust_cols),
    ("nominal", nominal_pipeline, nominal_cols),
    ("ordinal", ordinal_pipeline, ordinal_cols)
])

print(preprocessor)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['product_base_price', 'final_price',
#                                   'shipping_cost', 'days_to_deliver', 'rating',
#                                   'customer_age', 'customer_lifetime_value',
#                                   'session_duration_mins', 'pages_viewed']),
#                                 ('robust',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy...
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['category', 'sub_category', 'shipping_method',
#                                   'payment_method', 'customer_gender',
#                                   'country']),
#                                 ('ordinal',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(categories=[['Bronze',
#                                                                               'Silver',
#                                                                               'Gold',
#                                                                               'Platinum']]))]),
#                                  ['loyalty_tier'])])

# %%
df_processed = preprocessor.fit_transform(df)
print("Shape of processed data:", df_processed.shape)
# Out:
# Shape of processed data: (25885, 88)

# %%
X = df_processed
y = df["is_returned"]

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
